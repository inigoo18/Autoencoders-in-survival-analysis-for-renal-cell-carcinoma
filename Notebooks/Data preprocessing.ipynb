# %%
import os 
import numpy as np
import pandas as pd

# %% [markdown]
# This notebook shows how preprocessing is handled in the data.
#
# We transform the data in order to make them compatible with float type, as well as filtering some clinical and histology features out, and keeping those that are needed in the dataset.
#
# A bit more preprocessing can be found in the actual pipeline.

# %% [markdown]
# ## Preparing Genetic data

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = 'C://Users//inigo//Desktop//AAU//Cursos//4th semester//P10//Data//GeneticData.csv'

# Read the CSV file into a DataFrame
try:
    df = pd.read_csv(file_path, sep = ";", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
df
# Out:
#          X00936b9285d6b8665ae9122993fb8e91 X105622fadc33f23755ac2df823110aca  \
# HUGO
# A1BG                                  2,91                              9,61
# A1BG-AS1                              2,41                              0,71
# A1CF                                  4,71                              5,99
# A2M                                  10,78                              11,2
# A2M-AS1                               2,02                              0,45
# ...                                    ...                               ...
# ZYG11A                                0,01                              1,32
# ZYG11B                                4,12                              4,36
# ZYX                                   8,23                              7,66
# ZZEF1                                 5,45                              5,39
# ZZZ3                                  5,26                              5,03
#
#          Xe44f39747a8e84b02b4cb24659312144 X293dd1284496215e9a0eca9f17a98e7e  \
# HUGO
# A1BG                                  2,75                              2,17
# A1BG-AS1                              2,48                              0,69
# A1CF                                  1,46                              0,01
# A2M                                  11,18                             10,89
# A2M-AS1                                  2                              1,57
# ...                                    ...                               ...
# ZYG11A                                0,01                              0,43
# ZYG11B                                4,31                              4,16
# ZYX                                   9,11                              8,66
# ZZEF1                                 5,78                              6,04
# ZZZ3                                  5,26                              5,13
#
#          X01ed7190ce00862696edbf047b542045 Xf4a6a5a1450a8448882e1c0aebc0eea5  \
# HUGO
# A1BG                                  1,44                              1,52
# A1BG-AS1                              1,83                              0,01
# A1CF                                  2,35                              0,01
# A2M                                  10,11                              8,18
# A2M-AS1                               2,33                              2,93
# ...                                    ...                               ...
# ZYG11A                                0,01                              3,45
# ZYG11B                                4,45                              3,76
# ZYX                                   8,28                              8,66
# ZZEF1                                 5,56                              5,38
# ZZZ3                                  5,33                              5,26
#
#          Xf7ee4a331a8fd70edc240dff978c170d Xcddbd4d01bc7513298a5135e97cfdb6b  \
# HUGO
# A1BG                                  2,11                              2,15
# A1BG-AS1                              2,16                              1,31
# A1CF                                  0,01                              0,01
# A2M                                  11,74                              8,65
# A2M-AS1                               2,44                               1,2
# ...                                    ...                               ...
# ZYG11A                                0,01                              0,05
# ZYG11B                                4,55                              3,28
# ZYX                                   9,09                              9,13
# ZZEF1                                 6,11                              5,11
# ZZZ3                                  5,48                              4,89
#
#          Xa57451efa2822becb256706fe939d078 Xff8fbe2fe76c82d429d4fa1d315f3b93  \
# HUGO
# A1BG                                  2,26                              2,41
# A1BG-AS1                              2,21                              2,09
# A1CF                                  1,53                              0,01
# A2M                                   9,77                             10,49
# A2M-AS1                               1,86                              2,36
# ...                                    ...                               ...
# ZYG11A                                1,49                              0,41
# ZYG11B                                 4,2                                 4
# ZYX                                   8,26                              8,44
# ZZEF1                                 5,83                              5,99
# ZZZ3                                  5,36                              5,39
#
#           ... Xa7d2bd80340b4019986ea8d8c3638c75  \
# HUGO      ...
# A1BG      ...                              0,01
# A1BG-AS1  ...                              0,01
# A1CF      ...                              4,87
# A2M       ...                              8,91
# A2M-AS1   ...                              1,88
# ...       ...                               ...
# ZYG11A    ...                              4,19
# ZYG11B    ...                              4,25
# ZYX       ...                              7,89
# ZZEF1     ...                              5,67
# ZZZ3      ...                              5,61
#
#          Xbc7a029dc7ce4b19a5a2b78a7b2fc6ae X13b911b56a330efd2660b67b1cf98466  \
# HUGO
# A1BG                                  1,29                              2,76
# A1BG-AS1                              0,01                              1,81
# A1CF                                  3,32                              2,78
# A2M                                   9,15                              9,95
# A2M-AS1                                1,4                              2,58
# ...                                    ...                               ...
# ZYG11A                                2,54                              2,29
# ZYG11B                                3,67                                 4
# ZYX                                   8,25                              8,97
# ZZEF1                                 4,96                              5,77
# ZZZ3                                   4,5                              5,62
#
#          X9388bd484d0e404c6732573b4228d2a2 Xc3d410d70dd7359baa40126494fb6765  \
# HUGO
# A1BG                                  1,13                               0,8
# A1BG-AS1                              0,46                              0,01
# A1CF                                  4,48                              5,13
# A2M                                   8,37                              7,52
# A2M-AS1                               1,89                              2,71
# ...                                    ...                               ...
# ZYG11A                                0,01                               3,4
# ZYG11B                                3,61                               3,8
# ZYX                                   9,07                              7,53
# ZZEF1                                 4,97                              5,57
# ZZZ3                                  6,57                               5,9
#
#          X50772aa64efb859960b20f8801cd6f58 X91bcd3067a1a7954692d836515e04869  \
# HUGO
# A1BG                                  0,88                              1,33
# A1BG-AS1                              0,16                              1,16
# A1CF                                  4,16                              0,01
# A2M                                  10,06                              9,96
# A2M-AS1                               1,69                              1,64
# ...                                    ...                               ...
# ZYG11A                                 3,3                              0,01
# ZYG11B                                4,57                              4,06
# ZYX                                   8,23                              8,17
# ZZEF1                                 5,51                              5,81
# ZZZ3                                  5,66                              5,26
#
#          Xc7439a06ffa32b313b0ec1b987b992a2 X21a6043653d187f8bbead475d2f49791  \
# HUGO
# A1BG                                  1,74                               1,8
# A1BG-AS1                              0,56                              1,55
# A1CF                                   1,2                              3,14
# A2M                                   8,96                             10,25
# A2M-AS1                               0,64                              1,69
# ...                                    ...                               ...
# ZYG11A                                0,21                              0,01
# ZYG11B                                4,34                              4,39
# ZYX                                   7,93                              9,07
# ZZEF1                                  5,1                              5,92
# ZZZ3                                  5,02                              5,93
#
#          Xa021f5de25a2ffa059870f059a65d075
# HUGO
# A1BG                                  2,12
# A1BG-AS1                              1,05
# A1CF                                  3,41
# A2M                                   10,5
# A2M-AS1                               1,16
# ...                                    ...
# ZYG11A                                0,62
# ZYG11B                                3,96
# ZYX                                   9,06
# ZZEF1                                  5,4
# ZZZ3                                  4,98
#
# [22955 rows x 726 columns]

# %%
df_transposed = df.transpose()
df_transposed = df_transposed.replace(',', '.', regex=True)
df_transposed = df_transposed.astype(float)
df_transposed
# Out:
# HUGO                               A1BG  A1BG-AS1  A1CF    A2M  A2M-AS1  \
# X00936b9285d6b8665ae9122993fb8e91  2.91      2.41  4.71  10.78     2.02
# X105622fadc33f23755ac2df823110aca  9.61      0.71  5.99  11.20     0.45
# Xe44f39747a8e84b02b4cb24659312144  2.75      2.48  1.46  11.18     2.00
# X293dd1284496215e9a0eca9f17a98e7e  2.17      0.69  0.01  10.89     1.57
# X01ed7190ce00862696edbf047b542045  1.44      1.83  2.35  10.11     2.33
# ...                                 ...       ...   ...    ...      ...
# X50772aa64efb859960b20f8801cd6f58  0.88      0.16  4.16  10.06     1.69
# X91bcd3067a1a7954692d836515e04869  1.33      1.16  0.01   9.96     1.64
# Xc7439a06ffa32b313b0ec1b987b992a2  1.74      0.56  1.20   8.96     0.64
# X21a6043653d187f8bbead475d2f49791  1.80      1.55  3.14  10.25     1.69
# Xa021f5de25a2ffa059870f059a65d075  2.12      1.05  3.41  10.50     1.16
#
# HUGO                               A2ML1  A3GALT2  A4GALT  A4GNT  AAAS  ...  \
# X00936b9285d6b8665ae9122993fb8e91   0.01     0.01    7.18   0.01  6.22  ...
# X105622fadc33f23755ac2df823110aca   0.01     0.70    3.93   0.01  5.67  ...
# Xe44f39747a8e84b02b4cb24659312144   0.01     1.37    4.95   0.01  6.32  ...
# X293dd1284496215e9a0eca9f17a98e7e   0.01     0.49    5.14   1.62  6.36  ...
# X01ed7190ce00862696edbf047b542045   0.01     0.27    6.05   0.01  6.49  ...
# ...                                  ...      ...     ...    ...   ...  ...
# X50772aa64efb859960b20f8801cd6f58   0.01     0.01    6.18   0.01  5.91  ...
# X91bcd3067a1a7954692d836515e04869   0.01     1.35    5.57   0.01  6.14  ...
# Xc7439a06ffa32b313b0ec1b987b992a2   0.01     0.01    5.98   0.01  6.16  ...
# X21a6043653d187f8bbead475d2f49791   0.01     3.23    6.59   0.01  6.18  ...
# Xa021f5de25a2ffa059870f059a65d075   0.01     2.04    7.17   0.01  6.35  ...
#
# HUGO                               ZWILCH  ZWINT  ZXDA  ZXDB  ZXDC  ZYG11A  \
# X00936b9285d6b8665ae9122993fb8e91    3.18   3.96  3.82  3.83  2.86    0.01
# X105622fadc33f23755ac2df823110aca    2.62   2.59  3.64  4.10  2.86    1.32
# Xe44f39747a8e84b02b4cb24659312144    3.07   2.89  4.18  3.87  3.59    0.01
# X293dd1284496215e9a0eca9f17a98e7e    3.04   3.18  4.40  3.93  3.92    0.43
# X01ed7190ce00862696edbf047b542045    2.43   2.51  4.19  3.89  3.34    0.01
# ...                                   ...    ...   ...   ...   ...     ...
# X50772aa64efb859960b20f8801cd6f58    3.06   2.84  4.19  3.68  3.26    3.30
# X91bcd3067a1a7954692d836515e04869    4.06   4.12  3.38  3.47  3.60    0.01
# Xc7439a06ffa32b313b0ec1b987b992a2    3.01   3.77  4.44  4.30  2.92    0.21
# X21a6043653d187f8bbead475d2f49791    3.82   4.24  4.14  3.52  3.06    0.01
# Xa021f5de25a2ffa059870f059a65d075    2.81   4.31  3.58  3.38  4.24    0.62
#
# HUGO                               ZYG11B   ZYX  ZZEF1  ZZZ3
# X00936b9285d6b8665ae9122993fb8e91    4.12  8.23   5.45  5.26
# X105622fadc33f23755ac2df823110aca    4.36  7.66   5.39  5.03
# Xe44f39747a8e84b02b4cb24659312144    4.31  9.11   5.78  5.26
# X293dd1284496215e9a0eca9f17a98e7e    4.16  8.66   6.04  5.13
# X01ed7190ce00862696edbf047b542045    4.45  8.28   5.56  5.33
# ...                                   ...   ...    ...   ...
# X50772aa64efb859960b20f8801cd6f58    4.57  8.23   5.51  5.66
# X91bcd3067a1a7954692d836515e04869    4.06  8.17   5.81  5.26
# Xc7439a06ffa32b313b0ec1b987b992a2    4.34  7.93   5.10  5.02
# X21a6043653d187f8bbead475d2f49791    4.39  9.07   5.92  5.93
# Xa021f5de25a2ffa059870f059a65d075    3.96  9.06   5.40  4.98
#
# [726 rows x 22955 columns]

# %% [markdown]
# ##### Saving

# %%
df_transposed.to_csv('output_GeneticData.csv', index=True)

# %% [markdown]
# ##### Loading

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = 'output_GeneticData.csv'

# Read the CSV file into a DataFrame
try:
    df_genetic = pd.read_csv(file_path, sep = ",", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
df_genetic
# Out:
#                                    A1BG  A1BG-AS1  A1CF    A2M  A2M-AS1  \
# X00936b9285d6b8665ae9122993fb8e91  2.91      2.41  4.71  10.78     2.02
# X105622fadc33f23755ac2df823110aca  9.61      0.71  5.99  11.20     0.45
# Xe44f39747a8e84b02b4cb24659312144  2.75      2.48  1.46  11.18     2.00
# X293dd1284496215e9a0eca9f17a98e7e  2.17      0.69  0.01  10.89     1.57
# X01ed7190ce00862696edbf047b542045  1.44      1.83  2.35  10.11     2.33
# ...                                 ...       ...   ...    ...      ...
# X50772aa64efb859960b20f8801cd6f58  0.88      0.16  4.16  10.06     1.69
# X91bcd3067a1a7954692d836515e04869  1.33      1.16  0.01   9.96     1.64
# Xc7439a06ffa32b313b0ec1b987b992a2  1.74      0.56  1.20   8.96     0.64
# X21a6043653d187f8bbead475d2f49791  1.80      1.55  3.14  10.25     1.69
# Xa021f5de25a2ffa059870f059a65d075  2.12      1.05  3.41  10.50     1.16
#
#                                    A2ML1  A3GALT2  A4GALT  A4GNT  AAAS  ...  \
# X00936b9285d6b8665ae9122993fb8e91   0.01     0.01    7.18   0.01  6.22  ...
# X105622fadc33f23755ac2df823110aca   0.01     0.70    3.93   0.01  5.67  ...
# Xe44f39747a8e84b02b4cb24659312144   0.01     1.37    4.95   0.01  6.32  ...
# X293dd1284496215e9a0eca9f17a98e7e   0.01     0.49    5.14   1.62  6.36  ...
# X01ed7190ce00862696edbf047b542045   0.01     0.27    6.05   0.01  6.49  ...
# ...                                  ...      ...     ...    ...   ...  ...
# X50772aa64efb859960b20f8801cd6f58   0.01     0.01    6.18   0.01  5.91  ...
# X91bcd3067a1a7954692d836515e04869   0.01     1.35    5.57   0.01  6.14  ...
# Xc7439a06ffa32b313b0ec1b987b992a2   0.01     0.01    5.98   0.01  6.16  ...
# X21a6043653d187f8bbead475d2f49791   0.01     3.23    6.59   0.01  6.18  ...
# Xa021f5de25a2ffa059870f059a65d075   0.01     2.04    7.17   0.01  6.35  ...
#
#                                    ZWILCH  ZWINT  ZXDA  ZXDB  ZXDC  ZYG11A  \
# X00936b9285d6b8665ae9122993fb8e91    3.18   3.96  3.82  3.83  2.86    0.01
# X105622fadc33f23755ac2df823110aca    2.62   2.59  3.64  4.10  2.86    1.32
# Xe44f39747a8e84b02b4cb24659312144    3.07   2.89  4.18  3.87  3.59    0.01
# X293dd1284496215e9a0eca9f17a98e7e    3.04   3.18  4.40  3.93  3.92    0.43
# X01ed7190ce00862696edbf047b542045    2.43   2.51  4.19  3.89  3.34    0.01
# ...                                   ...    ...   ...   ...   ...     ...
# X50772aa64efb859960b20f8801cd6f58    3.06   2.84  4.19  3.68  3.26    3.30
# X91bcd3067a1a7954692d836515e04869    4.06   4.12  3.38  3.47  3.60    0.01
# Xc7439a06ffa32b313b0ec1b987b992a2    3.01   3.77  4.44  4.30  2.92    0.21
# X21a6043653d187f8bbead475d2f49791    3.82   4.24  4.14  3.52  3.06    0.01
# Xa021f5de25a2ffa059870f059a65d075    2.81   4.31  3.58  3.38  4.24    0.62
#
#                                    ZYG11B   ZYX  ZZEF1  ZZZ3
# X00936b9285d6b8665ae9122993fb8e91    4.12  8.23   5.45  5.26
# X105622fadc33f23755ac2df823110aca    4.36  7.66   5.39  5.03
# Xe44f39747a8e84b02b4cb24659312144    4.31  9.11   5.78  5.26
# X293dd1284496215e9a0eca9f17a98e7e    4.16  8.66   6.04  5.13
# X01ed7190ce00862696edbf047b542045    4.45  8.28   5.56  5.33
# ...                                   ...   ...    ...   ...
# X50772aa64efb859960b20f8801cd6f58    4.57  8.23   5.51  5.66
# X91bcd3067a1a7954692d836515e04869    4.06  8.17   5.81  5.26
# Xc7439a06ffa32b313b0ec1b987b992a2    4.34  7.93   5.10  5.02
# X21a6043653d187f8bbead475d2f49791    4.39  9.07   5.92  5.93
# Xa021f5de25a2ffa059870f059a65d075    3.96  9.06   5.40  4.98
#
# [726 rows x 22955 columns]

# %% [markdown]
# ------------------------

# %% [markdown]
# ## Preparing clinical data

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = 'C://Users//inigo//Desktop//AAU//Cursos//4th semester//P10//Data//ClinicalData.csv'

# Read the CSV file into a DataFrame
try:
    df = pd.read_csv(file_path, sep = ";", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
df
# Out:
#                                          PFS_P  PFS_P_CNSR  AGE SEX  \
# ID
# X00936b9285d6b8665ae9122993fb8e91    4,1724846         0.0   52   F
# X105622fadc33f23755ac2df823110aca  16,59137577         1.0   78   M
# Xeb5718fc91df508b1eb43b77df50a828  8,706365503         0.0   52   F
# Xe44f39747a8e84b02b4cb24659312144  11,10472279         0.0   61   M
# X293dd1284496215e9a0eca9f17a98e7e  14,02874743         1.0   55   M
# ...                                        ...         ...  ...  ..
# Xc7439a06ffa32b313b0ec1b987b992a2   6,50513347         1.0   43   M
# Xec760e642aeb6c4b26c912213d84f20b  6,866529774         1.0   65   F
# X21a6043653d187f8bbead475d2f49791  5,683778234         1.0   79   M
# Xa021f5de25a2ffa059870f059a65d075  4,106776181         1.0   73   F
# X05275c12e66dfefd10a3642818e862f7  8,344969199         1.0   62   F
#
#                                               TRT01P PDL1FL TCGA_cluster
# ID
# X00936b9285d6b8665ae9122993fb8e91  Avelumab+Axitinib      N           m1
# X105622fadc33f23755ac2df823110aca          Sunitinib      N           m1
# Xeb5718fc91df508b1eb43b77df50a828  Avelumab+Axitinib    NaN          NaN
# Xe44f39747a8e84b02b4cb24659312144          Sunitinib      Y           m2
# X293dd1284496215e9a0eca9f17a98e7e          Sunitinib      Y           m2
# ...                                              ...    ...          ...
# Xc7439a06ffa32b313b0ec1b987b992a2  Avelumab+Axitinib      N           m1
# Xec760e642aeb6c4b26c912213d84f20b  Avelumab+Axitinib      N          NaN
# X21a6043653d187f8bbead475d2f49791          Sunitinib      N           m3
# Xa021f5de25a2ffa059870f059a65d075  Avelumab+Axitinib      Y           m4
# X05275c12e66dfefd10a3642818e862f7  Avelumab+Axitinib      Y          NaN
#
# [886 rows x 7 columns]

# %%
# Replace for conversion to float from string
df['PFS_P'] = df['PFS_P'].replace(',', '.', regex=True)
df['PFS_P'] = df['PFS_P'].astype(float)

# Replace to 0 and 1 and keep NaN intact
df['PFS_P_CNSR'] = df['PFS_P_CNSR'].replace({0.0: 0, 1.0: 1})
df['PFS_P_CNSR'] = df['PFS_P_CNSR'].astype(pd.Int64Dtype())

df['PDL1FL'] = df['PDL1FL'].replace({'N': 0, 'Y': 1})
df['PDL1FL'] = df['PDL1FL'].astype(pd.Int64Dtype())

df
# Out:
#                                        PFS_P  PFS_P_CNSR  AGE SEX  \
# ID
# X00936b9285d6b8665ae9122993fb8e91   4.172485           0   52   F
# X105622fadc33f23755ac2df823110aca  16.591376           1   78   M
# Xeb5718fc91df508b1eb43b77df50a828   8.706366           0   52   F
# Xe44f39747a8e84b02b4cb24659312144  11.104723           0   61   M
# X293dd1284496215e9a0eca9f17a98e7e  14.028747           1   55   M
# ...                                      ...         ...  ...  ..
# Xc7439a06ffa32b313b0ec1b987b992a2   6.505133           1   43   M
# Xec760e642aeb6c4b26c912213d84f20b   6.866530           1   65   F
# X21a6043653d187f8bbead475d2f49791   5.683778           1   79   M
# Xa021f5de25a2ffa059870f059a65d075   4.106776           1   73   F
# X05275c12e66dfefd10a3642818e862f7   8.344969           1   62   F
#
#                                               TRT01P  PDL1FL TCGA_cluster
# ID
# X00936b9285d6b8665ae9122993fb8e91  Avelumab+Axitinib       0           m1
# X105622fadc33f23755ac2df823110aca          Sunitinib       0           m1
# Xeb5718fc91df508b1eb43b77df50a828  Avelumab+Axitinib    <NA>          NaN
# Xe44f39747a8e84b02b4cb24659312144          Sunitinib       1           m2
# X293dd1284496215e9a0eca9f17a98e7e          Sunitinib       1           m2
# ...                                              ...     ...          ...
# Xc7439a06ffa32b313b0ec1b987b992a2  Avelumab+Axitinib       0           m1
# Xec760e642aeb6c4b26c912213d84f20b  Avelumab+Axitinib       0          NaN
# X21a6043653d187f8bbead475d2f49791          Sunitinib       0           m3
# Xa021f5de25a2ffa059870f059a65d075  Avelumab+Axitinib       1           m4
# X05275c12e66dfefd10a3642818e862f7  Avelumab+Axitinib       1          NaN
#
# [886 rows x 7 columns]

# %%
df_nocli = df[['PFS_P', 'PFS_P_CNSR', 'TRT01P']]

index_gen = list(df_genetic.index)
index_cli = list(df_nocli.index)
inner_join = [x for x in index_gen if x in index_cli]

df_clinical = df_nocli[df_nocli.index.isin(inner_join)]
df_clinical.to_csv('output_ClinicalData.csv', index=True)

df_clinical
# Out:
#                                        PFS_P  PFS_P_CNSR             TRT01P
# ID
# X00936b9285d6b8665ae9122993fb8e91   4.172485           0  Avelumab+Axitinib
# X105622fadc33f23755ac2df823110aca  16.591376           1          Sunitinib
# Xe44f39747a8e84b02b4cb24659312144  11.104723           0          Sunitinib
# X293dd1284496215e9a0eca9f17a98e7e  14.028747           1          Sunitinib
# X01ed7190ce00862696edbf047b542045  12.418891           0          Sunitinib
# ...                                      ...         ...                ...
# X50772aa64efb859960b20f8801cd6f58   4.271047           0          Sunitinib
# X91bcd3067a1a7954692d836515e04869   2.496920           0          Sunitinib
# Xc7439a06ffa32b313b0ec1b987b992a2   6.505133           1  Avelumab+Axitinib
# X21a6043653d187f8bbead475d2f49791   5.683778           1          Sunitinib
# Xa021f5de25a2ffa059870f059a65d075   4.106776           1  Avelumab+Axitinib
#
# [726 rows x 3 columns]

# %% [markdown]
# #### Adding MATH scores and Histology data

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = '../Data/MATH_scores.csv'

# Read the CSV file into a DataFrame
try:
    df_math = pd.read_csv(file_path, sep = ";", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = '../Data/Histology_data.csv'

# Read the CSV file into a DataFrame
try:
    df_hist = pd.read_csv(file_path, sep = ";", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
df_math['MATH'] = df_math['MATH'].str.replace(',', '.')
df_math['MATH'] = df_math['MATH'].astype(float)
df_math
# Out:
#                                         MATH
# ANONID
# X00936b9285d6b8665ae9122993fb8e91  17.928391
# X105622fadc33f23755ac2df823110aca  16.122090
# Xe44f39747a8e84b02b4cb24659312144  23.616637
# X293dd1284496215e9a0eca9f17a98e7e  24.817435
# X01ed7190ce00862696edbf047b542045  19.303863
# ...                                      ...
# X91bcd3067a1a7954692d836515e04869  27.837848
# Xc7439a06ffa32b313b0ec1b987b992a2  26.606826
# X21a6043653d187f8bbead475d2f49791  17.627516
# Xa021f5de25a2ffa059870f059a65d075  16.266771
# X05275c12e66dfefd10a3642818e862f7  25.551191
#
# [738 rows x 1 columns]

# %%
pd.merge(df_math, df_clinical, left_index = True, right_index = True, how = 'inner')
# Out:
#                                         MATH      PFS_P  PFS_P_CNSR  \
# X00936b9285d6b8665ae9122993fb8e91  17.928391   4.172485           0
# X105622fadc33f23755ac2df823110aca  16.122090  16.591376           1
# Xe44f39747a8e84b02b4cb24659312144  23.616637  11.104723           0
# X293dd1284496215e9a0eca9f17a98e7e  24.817435  14.028747           1
# X01ed7190ce00862696edbf047b542045  19.303863  12.418891           0
# ...                                      ...        ...         ...
# X50772aa64efb859960b20f8801cd6f58  15.672304   4.271047           0
# X91bcd3067a1a7954692d836515e04869  27.837848   2.496920           0
# Xc7439a06ffa32b313b0ec1b987b992a2  26.606826   6.505133           1
# X21a6043653d187f8bbead475d2f49791  17.627516   5.683778           1
# Xa021f5de25a2ffa059870f059a65d075  16.266771   4.106776           1
#
#                                               TRT01P
# X00936b9285d6b8665ae9122993fb8e91  Avelumab+Axitinib
# X105622fadc33f23755ac2df823110aca          Sunitinib
# Xe44f39747a8e84b02b4cb24659312144          Sunitinib
# X293dd1284496215e9a0eca9f17a98e7e          Sunitinib
# X01ed7190ce00862696edbf047b542045          Sunitinib
# ...                                              ...
# X50772aa64efb859960b20f8801cd6f58          Sunitinib
# X91bcd3067a1a7954692d836515e04869          Sunitinib
# Xc7439a06ffa32b313b0ec1b987b992a2  Avelumab+Axitinib
# X21a6043653d187f8bbead475d2f49791          Sunitinib
# Xa021f5de25a2ffa059870f059a65d075  Avelumab+Axitinib
#
# [691 rows x 4 columns]

# %%
# merging clinical and MATH makes us lose around 30/40 patients
#merged_df = pd.merge(df_math, df_clinical, left_index=True, right_index=True, how='inner')
clinical_df = pd.merge(df_clinical, df_hist, left_index=True, right_index=True, how='inner')
cols = ['CD8_INVASIVE_MARGIN_SURFACE_AREA', 'CD8_POSITIVE_CELLS_TUMOR_CENTER', 'CD8_POSITIVE_CELLS_INVASIVE_MARGIN', 'CD8_POSITIVE_CELLS_TOTAL_AREA']
colsToRemove = ['CD8_INVASIVE_MARGIN_SURFACE_AREA', 'CD8_POSITIVE_CELLS_TUMOR_CENTER', 'CD8_POSITIVE_CELLS_INVASIVE_MARGIN', 'CD8_POSITIVE_CELLS_TOTAL_AREA'] # over 50% missing values
for i in cols:
    clinical_df[i] = clinical_df[i].str.replace(',', '.')
    clinical_df[i] = clinical_df[i].astype(float)
# We first drop those columns with +50% missing, then do dropna to remove those patients that don't have a value in CD8 positive tumor center (5% missing)
clinical_df = clinical_df.drop(columns = colsToRemove)
#clinical_df = clinical_df.dropna()
clinical_df
# Out:
#                                        PFS_P  PFS_P_CNSR             TRT01P  \
# ID
# X00936b9285d6b8665ae9122993fb8e91   4.172485           0  Avelumab+Axitinib
# X105622fadc33f23755ac2df823110aca  16.591376           1          Sunitinib
# Xe44f39747a8e84b02b4cb24659312144  11.104723           0          Sunitinib
# X293dd1284496215e9a0eca9f17a98e7e  14.028747           1          Sunitinib
# X01ed7190ce00862696edbf047b542045  12.418891           0          Sunitinib
# ...                                      ...         ...                ...
# X50772aa64efb859960b20f8801cd6f58   4.271047           0          Sunitinib
# X91bcd3067a1a7954692d836515e04869   2.496920           0          Sunitinib
# Xc7439a06ffa32b313b0ec1b987b992a2   6.505133           1  Avelumab+Axitinib
# X21a6043653d187f8bbead475d2f49791   5.683778           1          Sunitinib
# Xa021f5de25a2ffa059870f059a65d075   4.106776           1  Avelumab+Axitinib
#
#                                    HE_TUMOR_CELL_CONTENT_IN_TUMOR_AREA  \
# ID
# X00936b9285d6b8665ae9122993fb8e91                                 70.0
# X105622fadc33f23755ac2df823110aca                                 85.0
# Xe44f39747a8e84b02b4cb24659312144                                 80.0
# X293dd1284496215e9a0eca9f17a98e7e                                 60.0
# X01ed7190ce00862696edbf047b542045                                 80.0
# ...                                                                ...
# X50772aa64efb859960b20f8801cd6f58                                 75.0
# X91bcd3067a1a7954692d836515e04869                                 50.0
# Xc7439a06ffa32b313b0ec1b987b992a2                                 80.0
# X21a6043653d187f8bbead475d2f49791                                 70.0
# Xa021f5de25a2ffa059870f059a65d075                                 75.0
#
#                                    PD-L1_TOTAL_IMMUNE_CELLS_PER_TUMOR_AREA
# ID
# X00936b9285d6b8665ae9122993fb8e91                                      0.0
# X105622fadc33f23755ac2df823110aca                                      1.0
# Xe44f39747a8e84b02b4cb24659312144                                      5.0
# X293dd1284496215e9a0eca9f17a98e7e                                      5.0
# X01ed7190ce00862696edbf047b542045                                      2.0
# ...                                                                    ...
# X50772aa64efb859960b20f8801cd6f58                                      1.0
# X91bcd3067a1a7954692d836515e04869                                      1.0
# Xc7439a06ffa32b313b0ec1b987b992a2                                      1.0
# X21a6043653d187f8bbead475d2f49791                                      0.0
# Xa021f5de25a2ffa059870f059a65d075                                      1.0
#
# [726 rows x 5 columns]

# %% [markdown]
# ##### Saving

# %%
clinical_df.to_csv('output_ClinicalData.csv', index=True)

# %% [markdown]
# ##### Loading

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = 'output_ClinicalDataWithHistology.csv'

# Read the CSV file into a DataFrame
try:
    df_clinical = pd.read_csv(file_path, sep = ",", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
df_clinical
# Out:
#                                         MATH      PFS_P  PFS_P_CNSR  AGE SEX  \
# X00936b9285d6b8665ae9122993fb8e91  17.928391   4.172485           0   52   F
# X105622fadc33f23755ac2df823110aca  16.122090  16.591376           1   78   M
# Xe44f39747a8e84b02b4cb24659312144  23.616637  11.104723           0   61   M
# X293dd1284496215e9a0eca9f17a98e7e  24.817435  14.028747           1   55   M
# X01ed7190ce00862696edbf047b542045  19.303863  12.418891           0   68   M
# ...                                      ...        ...         ...  ...  ..
# Xc3d410d70dd7359baa40126494fb6765  24.552611   9.790554           1   49   M
# X50772aa64efb859960b20f8801cd6f58  15.672304   4.271047           0   65   M
# X91bcd3067a1a7954692d836515e04869  27.837848   2.496920           0   57   M
# Xc7439a06ffa32b313b0ec1b987b992a2  26.606826   6.505133           1   43   M
# X21a6043653d187f8bbead475d2f49791  17.627516   5.683778           1   79   M
#
#                                               TRT01P  PDL1FL TCGA_cluster  \
# X00936b9285d6b8665ae9122993fb8e91  Avelumab+Axitinib       0           m1
# X105622fadc33f23755ac2df823110aca          Sunitinib       0           m1
# Xe44f39747a8e84b02b4cb24659312144          Sunitinib       1           m2
# X293dd1284496215e9a0eca9f17a98e7e          Sunitinib       1           m2
# X01ed7190ce00862696edbf047b542045          Sunitinib       1           m1
# ...                                              ...     ...          ...
# Xc3d410d70dd7359baa40126494fb6765          Sunitinib       0           m1
# X50772aa64efb859960b20f8801cd6f58          Sunitinib       0           m1
# X91bcd3067a1a7954692d836515e04869          Sunitinib       1           m3
# Xc7439a06ffa32b313b0ec1b987b992a2  Avelumab+Axitinib       0           m1
# X21a6043653d187f8bbead475d2f49791          Sunitinib       0           m3
#
#                                    HE_TUMOR_CELL_CONTENT_IN_TUMOR_AREA  \
# X00936b9285d6b8665ae9122993fb8e91                                 70.0
# X105622fadc33f23755ac2df823110aca                                 85.0
# Xe44f39747a8e84b02b4cb24659312144                                 80.0
# X293dd1284496215e9a0eca9f17a98e7e                                 60.0
# X01ed7190ce00862696edbf047b542045                                 80.0
# ...                                                                ...
# Xc3d410d70dd7359baa40126494fb6765                                 75.0
# X50772aa64efb859960b20f8801cd6f58                                 75.0
# X91bcd3067a1a7954692d836515e04869                                 50.0
# Xc7439a06ffa32b313b0ec1b987b992a2                                 80.0
# X21a6043653d187f8bbead475d2f49791                                 70.0
#
#                                    CD8_POSITIVE_CELLS_TUMOR_CENTER  \
# X00936b9285d6b8665ae9122993fb8e91                             0.08
# X105622fadc33f23755ac2df823110aca                             0.12
# Xe44f39747a8e84b02b4cb24659312144                             0.92
# X293dd1284496215e9a0eca9f17a98e7e                             3.16
# X01ed7190ce00862696edbf047b542045                             1.98
# ...                                                            ...
# Xc3d410d70dd7359baa40126494fb6765                             1.01
# X50772aa64efb859960b20f8801cd6f58                             1.10
# X91bcd3067a1a7954692d836515e04869                             4.03
# Xc7439a06ffa32b313b0ec1b987b992a2                             0.14
# X21a6043653d187f8bbead475d2f49791                             3.10
#
#                                    PD-L1_TOTAL_IMMUNE_CELLS_PER_TUMOR_AREA  \
# X00936b9285d6b8665ae9122993fb8e91                                      0.0
# X105622fadc33f23755ac2df823110aca                                      1.0
# Xe44f39747a8e84b02b4cb24659312144                                      5.0
# X293dd1284496215e9a0eca9f17a98e7e                                      5.0
# X01ed7190ce00862696edbf047b542045                                      2.0
# ...                                                                    ...
# Xc3d410d70dd7359baa40126494fb6765                                      0.0
# X50772aa64efb859960b20f8801cd6f58                                      1.0
# X91bcd3067a1a7954692d836515e04869                                      1.0
# Xc7439a06ffa32b313b0ec1b987b992a2                                      1.0
# X21a6043653d187f8bbead475d2f49791                                      0.0
#
#                                    CD8_POSITIVE_CELLS_TOTAL_AREA
# X00936b9285d6b8665ae9122993fb8e91                         0.1931
# X105622fadc33f23755ac2df823110aca                         0.1214
# Xe44f39747a8e84b02b4cb24659312144                         0.9203
# X293dd1284496215e9a0eca9f17a98e7e                         3.1635
# X01ed7190ce00862696edbf047b542045                         2.0708
# ...                                                          ...
# Xc3d410d70dd7359baa40126494fb6765                         1.0089
# X50772aa64efb859960b20f8801cd6f58                         1.1775
# X91bcd3067a1a7954692d836515e04869                         3.9642
# Xc7439a06ffa32b313b0ec1b987b992a2                         0.1417
# X21a6043653d187f8bbead475d2f49791                         3.1024
#
# [650 rows x 12 columns]

# %% [markdown]
# ---------------------

# %%
index_gen = list(df_genetic.index)
index_cli = list(df_clinical.index)
inner_join = [x for x in index_gen if x in index_cli]

left_over = [x for x in index_cli if x not in inner_join]

print(len(inner_join), "are in both genetic and clinical table while", len(left_over), "are not")
# Out:
# 650 are in both genetic and clinical table while 0 are not

# %%
df_genetic = df_genetic[df_genetic.index.isin(inner_join)]
df_clinical = df_clinical[df_clinical.index.isin(inner_join)]

# %%
df_genetic.to_csv('output_GeneticDataWithHistology.csv', index=True)
df_clinical.to_csv('output_ClinicalDataWithHistology.csv', index=True)

# %% [markdown]
# --------------------

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = 'output_ClinicalData.csv'

# Read the CSV file into a DataFrame
try:
    df_clinical = pd.read_csv(file_path, sep = ",", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = 'output_GeneticData.csv'

# Read the CSV file into a DataFrame
try:
    df_genetic = pd.read_csv(file_path, sep = ",", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
df_clinical
# Out:
#                                        PFS_P  PFS_P_CNSR             TRT01P  \
# ID
# X00936b9285d6b8665ae9122993fb8e91   4.172485           0  Avelumab+Axitinib
# X105622fadc33f23755ac2df823110aca  16.591376           1          Sunitinib
# Xe44f39747a8e84b02b4cb24659312144  11.104723           0          Sunitinib
# X293dd1284496215e9a0eca9f17a98e7e  14.028747           1          Sunitinib
# X01ed7190ce00862696edbf047b542045  12.418891           0          Sunitinib
# ...                                      ...         ...                ...
# X50772aa64efb859960b20f8801cd6f58   4.271047           0          Sunitinib
# X91bcd3067a1a7954692d836515e04869   2.496920           0          Sunitinib
# Xc7439a06ffa32b313b0ec1b987b992a2   6.505133           1  Avelumab+Axitinib
# X21a6043653d187f8bbead475d2f49791   5.683778           1          Sunitinib
# Xa021f5de25a2ffa059870f059a65d075   4.106776           1  Avelumab+Axitinib
#
#                                    HE_TUMOR_CELL_CONTENT_IN_TUMOR_AREA  \
# ID
# X00936b9285d6b8665ae9122993fb8e91                                 70.0
# X105622fadc33f23755ac2df823110aca                                 85.0
# Xe44f39747a8e84b02b4cb24659312144                                 80.0
# X293dd1284496215e9a0eca9f17a98e7e                                 60.0
# X01ed7190ce00862696edbf047b542045                                 80.0
# ...                                                                ...
# X50772aa64efb859960b20f8801cd6f58                                 75.0
# X91bcd3067a1a7954692d836515e04869                                 50.0
# Xc7439a06ffa32b313b0ec1b987b992a2                                 80.0
# X21a6043653d187f8bbead475d2f49791                                 70.0
# Xa021f5de25a2ffa059870f059a65d075                                 75.0
#
#                                    PD-L1_TOTAL_IMMUNE_CELLS_PER_TUMOR_AREA
# ID
# X00936b9285d6b8665ae9122993fb8e91                                      0.0
# X105622fadc33f23755ac2df823110aca                                      1.0
# Xe44f39747a8e84b02b4cb24659312144                                      5.0
# X293dd1284496215e9a0eca9f17a98e7e                                      5.0
# X01ed7190ce00862696edbf047b542045                                      2.0
# ...                                                                    ...
# X50772aa64efb859960b20f8801cd6f58                                      1.0
# X91bcd3067a1a7954692d836515e04869                                      1.0
# Xc7439a06ffa32b313b0ec1b987b992a2                                      1.0
# X21a6043653d187f8bbead475d2f49791                                      0.0
# Xa021f5de25a2ffa059870f059a65d075                                      1.0
#
# [726 rows x 5 columns]

# %%
df_genetic
# Out:
#                                    A1BG  A1BG-AS1  A1CF    A2M  A2M-AS1  \
# X00936b9285d6b8665ae9122993fb8e91  2.91      2.41  4.71  10.78     2.02
# X105622fadc33f23755ac2df823110aca  9.61      0.71  5.99  11.20     0.45
# Xe44f39747a8e84b02b4cb24659312144  2.75      2.48  1.46  11.18     2.00
# X293dd1284496215e9a0eca9f17a98e7e  2.17      0.69  0.01  10.89     1.57
# X01ed7190ce00862696edbf047b542045  1.44      1.83  2.35  10.11     2.33
# ...                                 ...       ...   ...    ...      ...
# X50772aa64efb859960b20f8801cd6f58  0.88      0.16  4.16  10.06     1.69
# X91bcd3067a1a7954692d836515e04869  1.33      1.16  0.01   9.96     1.64
# Xc7439a06ffa32b313b0ec1b987b992a2  1.74      0.56  1.20   8.96     0.64
# X21a6043653d187f8bbead475d2f49791  1.80      1.55  3.14  10.25     1.69
# Xa021f5de25a2ffa059870f059a65d075  2.12      1.05  3.41  10.50     1.16
#
#                                    A2ML1  A3GALT2  A4GALT  A4GNT  AAAS  ...  \
# X00936b9285d6b8665ae9122993fb8e91   0.01     0.01    7.18   0.01  6.22  ...
# X105622fadc33f23755ac2df823110aca   0.01     0.70    3.93   0.01  5.67  ...
# Xe44f39747a8e84b02b4cb24659312144   0.01     1.37    4.95   0.01  6.32  ...
# X293dd1284496215e9a0eca9f17a98e7e   0.01     0.49    5.14   1.62  6.36  ...
# X01ed7190ce00862696edbf047b542045   0.01     0.27    6.05   0.01  6.49  ...
# ...                                  ...      ...     ...    ...   ...  ...
# X50772aa64efb859960b20f8801cd6f58   0.01     0.01    6.18   0.01  5.91  ...
# X91bcd3067a1a7954692d836515e04869   0.01     1.35    5.57   0.01  6.14  ...
# Xc7439a06ffa32b313b0ec1b987b992a2   0.01     0.01    5.98   0.01  6.16  ...
# X21a6043653d187f8bbead475d2f49791   0.01     3.23    6.59   0.01  6.18  ...
# Xa021f5de25a2ffa059870f059a65d075   0.01     2.04    7.17   0.01  6.35  ...
#
#                                    ZWILCH  ZWINT  ZXDA  ZXDB  ZXDC  ZYG11A  \
# X00936b9285d6b8665ae9122993fb8e91    3.18   3.96  3.82  3.83  2.86    0.01
# X105622fadc33f23755ac2df823110aca    2.62   2.59  3.64  4.10  2.86    1.32
# Xe44f39747a8e84b02b4cb24659312144    3.07   2.89  4.18  3.87  3.59    0.01
# X293dd1284496215e9a0eca9f17a98e7e    3.04   3.18  4.40  3.93  3.92    0.43
# X01ed7190ce00862696edbf047b542045    2.43   2.51  4.19  3.89  3.34    0.01
# ...                                   ...    ...   ...   ...   ...     ...
# X50772aa64efb859960b20f8801cd6f58    3.06   2.84  4.19  3.68  3.26    3.30
# X91bcd3067a1a7954692d836515e04869    4.06   4.12  3.38  3.47  3.60    0.01
# Xc7439a06ffa32b313b0ec1b987b992a2    3.01   3.77  4.44  4.30  2.92    0.21
# X21a6043653d187f8bbead475d2f49791    3.82   4.24  4.14  3.52  3.06    0.01
# Xa021f5de25a2ffa059870f059a65d075    2.81   4.31  3.58  3.38  4.24    0.62
#
#                                    ZYG11B   ZYX  ZZEF1  ZZZ3
# X00936b9285d6b8665ae9122993fb8e91    4.12  8.23   5.45  5.26
# X105622fadc33f23755ac2df823110aca    4.36  7.66   5.39  5.03
# Xe44f39747a8e84b02b4cb24659312144    4.31  9.11   5.78  5.26
# X293dd1284496215e9a0eca9f17a98e7e    4.16  8.66   6.04  5.13
# X01ed7190ce00862696edbf047b542045    4.45  8.28   5.56  5.33
# ...                                   ...   ...    ...   ...
# X50772aa64efb859960b20f8801cd6f58    4.57  8.23   5.51  5.66
# X91bcd3067a1a7954692d836515e04869    4.06  8.17   5.81  5.26
# Xc7439a06ffa32b313b0ec1b987b992a2    4.34  7.93   5.10  5.02
# X21a6043653d187f8bbead475d2f49791    4.39  9.07   5.92  5.93
# Xa021f5de25a2ffa059870f059a65d075    3.96  9.06   5.40  4.98
#
# [726 rows x 22955 columns]
