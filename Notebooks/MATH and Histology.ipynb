# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import ConnectionPatch
import math

# %% [markdown]
# In our work we don't incorporate MATH scores because not every patient has the value measured. However, this notebook explains how its preprocessed.

# %% [markdown]
# ### MATH scores

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = '../Data/MATH_scores.csv'

# Read the CSV file into a DataFrame
try:
    df_math = pd.read_csv(file_path, sep = ";", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
df_math['MATH'] = df_math['MATH'].str.replace(',', '.')
df_math['MATH'] = df_math['MATH'].astype(float)
df_math
# Out:
#                                         MATH
# ANONID
# X00936b9285d6b8665ae9122993fb8e91  17.928391
# X105622fadc33f23755ac2df823110aca  16.122090
# Xe44f39747a8e84b02b4cb24659312144  23.616637
# X293dd1284496215e9a0eca9f17a98e7e  24.817435
# X01ed7190ce00862696edbf047b542045  19.303863
# ...                                      ...
# X91bcd3067a1a7954692d836515e04869  27.837848
# Xc7439a06ffa32b313b0ec1b987b992a2  26.606826
# X21a6043653d187f8bbead475d2f49791  17.627516
# Xa021f5de25a2ffa059870f059a65d075  16.266771
# X05275c12e66dfefd10a3642818e862f7  25.551191
#
# [738 rows x 1 columns]

# %%
df_math.iloc[0]
# Out:
# MATH    17.928391
# Name: X00936b9285d6b8665ae9122993fb8e91, dtype: float64

# %% [markdown]
# ### CLINICAL data

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = 'output_ClinicalData.csv'

# Read the CSV file into a DataFrame
try:
    df_cli = pd.read_csv(file_path, sep = ",", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
df_cli
# Out:
#                                        PFS_P  PFS_P_CNSR  AGE SEX  \
# ID
# X00936b9285d6b8665ae9122993fb8e91   4.172485         0.0   52   F
# X105622fadc33f23755ac2df823110aca  16.591376         1.0   78   M
# Xeb5718fc91df508b1eb43b77df50a828   8.706366         0.0   52   F
# Xe44f39747a8e84b02b4cb24659312144  11.104723         0.0   61   M
# X293dd1284496215e9a0eca9f17a98e7e  14.028747         1.0   55   M
# ...                                      ...         ...  ...  ..
# Xc7439a06ffa32b313b0ec1b987b992a2   6.505133         1.0   43   M
# Xec760e642aeb6c4b26c912213d84f20b   6.866530         1.0   65   F
# X21a6043653d187f8bbead475d2f49791   5.683778         1.0   79   M
# Xa021f5de25a2ffa059870f059a65d075   4.106776         1.0   73   F
# X05275c12e66dfefd10a3642818e862f7   8.344969         1.0   62   F
#
#                                               TRT01P  PDL1FL TCGA_cluster
# ID
# X00936b9285d6b8665ae9122993fb8e91  Avelumab+Axitinib     0.0           m1
# X105622fadc33f23755ac2df823110aca          Sunitinib     0.0           m1
# Xeb5718fc91df508b1eb43b77df50a828  Avelumab+Axitinib     NaN          NaN
# Xe44f39747a8e84b02b4cb24659312144          Sunitinib     1.0           m2
# X293dd1284496215e9a0eca9f17a98e7e          Sunitinib     1.0           m2
# ...                                              ...     ...          ...
# Xc7439a06ffa32b313b0ec1b987b992a2  Avelumab+Axitinib     0.0           m1
# Xec760e642aeb6c4b26c912213d84f20b  Avelumab+Axitinib     0.0          NaN
# X21a6043653d187f8bbead475d2f49791          Sunitinib     0.0           m3
# Xa021f5de25a2ffa059870f059a65d075  Avelumab+Axitinib     1.0           m4
# X05275c12e66dfefd10a3642818e862f7  Avelumab+Axitinib     1.0          NaN
#
# [886 rows x 7 columns]

# %% [markdown]
# ### HISTOLOGY data

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = '../Data/Histology_data.csv'

# Read the CSV file into a DataFrame
try:
    df_hist = pd.read_csv(file_path, sep = ";", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
merged_df = pd.merge(df_math, df_cli, left_index=True, right_index=True, how='inner')
clinical_df = pd.merge(merged_df, df_hist, left_index=True, right_index=True, how='inner')
cols = ['CD8_INVASIVE_MARGIN_SURFACE_AREA', 'CD8_POSITIVE_CELLS_TUMOR_CENTER', 'CD8_POSITIVE_CELLS_INVASIVE_MARGIN', 'CD8_POSITIVE_CELLS_TOTAL_AREA']
for i in cols:
    clinical_df[i] = clinical_df[i].str.replace(',', '.')
    clinical_df[i] = clinical_df[i].astype(float)
clinical_df
# Out:
#                                         MATH      PFS_P  PFS_P_CNSR  AGE SEX  \
# X00936b9285d6b8665ae9122993fb8e91  17.928391   4.172485         0.0   52   F
# X105622fadc33f23755ac2df823110aca  16.122090  16.591376         1.0   78   M
# Xe44f39747a8e84b02b4cb24659312144  23.616637  11.104723         0.0   61   M
# X293dd1284496215e9a0eca9f17a98e7e  24.817435  14.028747         1.0   55   M
# X01ed7190ce00862696edbf047b542045  19.303863  12.418891         0.0   68   M
# ...                                      ...        ...         ...  ...  ..
# X91bcd3067a1a7954692d836515e04869  27.837848   2.496920         0.0   57   M
# Xc7439a06ffa32b313b0ec1b987b992a2  26.606826   6.505133         1.0   43   M
# X21a6043653d187f8bbead475d2f49791  17.627516   5.683778         1.0   79   M
# Xa021f5de25a2ffa059870f059a65d075  16.266771   4.106776         1.0   73   F
# X05275c12e66dfefd10a3642818e862f7  25.551191   8.344969         1.0   62   F
#
#                                               TRT01P  PDL1FL TCGA_cluster  \
# X00936b9285d6b8665ae9122993fb8e91  Avelumab+Axitinib     0.0           m1
# X105622fadc33f23755ac2df823110aca          Sunitinib     0.0           m1
# Xe44f39747a8e84b02b4cb24659312144          Sunitinib     1.0           m2
# X293dd1284496215e9a0eca9f17a98e7e          Sunitinib     1.0           m2
# X01ed7190ce00862696edbf047b542045          Sunitinib     1.0           m1
# ...                                              ...     ...          ...
# X91bcd3067a1a7954692d836515e04869          Sunitinib     1.0           m3
# Xc7439a06ffa32b313b0ec1b987b992a2  Avelumab+Axitinib     0.0           m1
# X21a6043653d187f8bbead475d2f49791          Sunitinib     0.0           m3
# Xa021f5de25a2ffa059870f059a65d075  Avelumab+Axitinib     1.0           m4
# X05275c12e66dfefd10a3642818e862f7  Avelumab+Axitinib     1.0          NaN
#
#                                    HE_TUMOR_CELL_CONTENT_IN_TUMOR_AREA  \
# X00936b9285d6b8665ae9122993fb8e91                                 70.0
# X105622fadc33f23755ac2df823110aca                                 85.0
# Xe44f39747a8e84b02b4cb24659312144                                 80.0
# X293dd1284496215e9a0eca9f17a98e7e                                 60.0
# X01ed7190ce00862696edbf047b542045                                 80.0
# ...                                                                ...
# X91bcd3067a1a7954692d836515e04869                                 50.0
# Xc7439a06ffa32b313b0ec1b987b992a2                                 80.0
# X21a6043653d187f8bbead475d2f49791                                 70.0
# Xa021f5de25a2ffa059870f059a65d075                                 75.0
# X05275c12e66dfefd10a3642818e862f7                                 85.0
#
#                                    CD8_INVASIVE_MARGIN_SURFACE_AREA  \
# X00936b9285d6b8665ae9122993fb8e91                           13.3235
# X105622fadc33f23755ac2df823110aca                               NaN
# Xe44f39747a8e84b02b4cb24659312144                            5.4150
# X293dd1284496215e9a0eca9f17a98e7e                               NaN
# X01ed7190ce00862696edbf047b542045                           12.6629
# ...                                                             ...
# X91bcd3067a1a7954692d836515e04869                           11.7334
# Xc7439a06ffa32b313b0ec1b987b992a2                               NaN
# X21a6043653d187f8bbead475d2f49791                               NaN
# Xa021f5de25a2ffa059870f059a65d075                               NaN
# X05275c12e66dfefd10a3642818e862f7                           15.8177
#
#                                    CD8_POSITIVE_CELLS_TUMOR_CENTER  \
# X00936b9285d6b8665ae9122993fb8e91                             0.08
# X105622fadc33f23755ac2df823110aca                             0.12
# Xe44f39747a8e84b02b4cb24659312144                             0.92
# X293dd1284496215e9a0eca9f17a98e7e                             3.16
# X01ed7190ce00862696edbf047b542045                             1.98
# ...                                                            ...
# X91bcd3067a1a7954692d836515e04869                             4.03
# Xc7439a06ffa32b313b0ec1b987b992a2                             0.14
# X21a6043653d187f8bbead475d2f49791                             3.10
# Xa021f5de25a2ffa059870f059a65d075                              NaN
# X05275c12e66dfefd10a3642818e862f7                             0.10
#
#                                    PD-L1_TOTAL_IMMUNE_CELLS_PER_TUMOR_AREA  \
# X00936b9285d6b8665ae9122993fb8e91                                      0.0
# X105622fadc33f23755ac2df823110aca                                      1.0
# Xe44f39747a8e84b02b4cb24659312144                                      5.0
# X293dd1284496215e9a0eca9f17a98e7e                                      5.0
# X01ed7190ce00862696edbf047b542045                                      2.0
# ...                                                                    ...
# X91bcd3067a1a7954692d836515e04869                                      1.0
# Xc7439a06ffa32b313b0ec1b987b992a2                                      1.0
# X21a6043653d187f8bbead475d2f49791                                      0.0
# Xa021f5de25a2ffa059870f059a65d075                                      1.0
# X05275c12e66dfefd10a3642818e862f7                                      1.0
#
#                                    CD8_POSITIVE_CELLS_INVASIVE_MARGIN  \
# X00936b9285d6b8665ae9122993fb8e91                                0.65
# X105622fadc33f23755ac2df823110aca                                 NaN
# Xe44f39747a8e84b02b4cb24659312144                                0.92
# X293dd1284496215e9a0eca9f17a98e7e                                 NaN
# X01ed7190ce00862696edbf047b542045                                2.61
# ...                                                               ...
# X91bcd3067a1a7954692d836515e04869                                3.65
# Xc7439a06ffa32b313b0ec1b987b992a2                                 NaN
# X21a6043653d187f8bbead475d2f49791                                 NaN
# Xa021f5de25a2ffa059870f059a65d075                                 NaN
# X05275c12e66dfefd10a3642818e862f7                                1.34
#
#                                    CD8_POSITIVE_CELLS_TOTAL_AREA
# X00936b9285d6b8665ae9122993fb8e91                         0.1931
# X105622fadc33f23755ac2df823110aca                         0.1214
# Xe44f39747a8e84b02b4cb24659312144                         0.9203
# X293dd1284496215e9a0eca9f17a98e7e                         3.1635
# X01ed7190ce00862696edbf047b542045                         2.0708
# ...                                                          ...
# X91bcd3067a1a7954692d836515e04869                         3.9642
# Xc7439a06ffa32b313b0ec1b987b992a2                         0.1417
# X21a6043653d187f8bbead475d2f49791                         3.1024
# Xa021f5de25a2ffa059870f059a65d075                            NaN
# X05275c12e66dfefd10a3642818e862f7                         0.5388
#
# [738 rows x 14 columns]

# %%
clinical_df.dtypes
# Out:
# MATH                                       float64
# PFS_P                                      float64
# PFS_P_CNSR                                 float64
# AGE                                          int64
# SEX                                         object
# TRT01P                                      object
# PDL1FL                                     float64
# TCGA_cluster                                object
# HE_TUMOR_CELL_CONTENT_IN_TUMOR_AREA        float64
# CD8_INVASIVE_MARGIN_SURFACE_AREA           float64
# CD8_POSITIVE_CELLS_TUMOR_CENTER            float64
# PD-L1_TOTAL_IMMUNE_CELLS_PER_TUMOR_AREA    float64
# CD8_POSITIVE_CELLS_INVASIVE_MARGIN         float64
# CD8_POSITIVE_CELLS_TOTAL_AREA              float64
# dtype: object
