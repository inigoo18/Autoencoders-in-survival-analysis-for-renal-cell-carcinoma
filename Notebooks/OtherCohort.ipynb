# %%
import os 
import numpy as np
import pandas as pd

# %% [markdown]
# ### Saving graph columns

# %%
current_directory = os.getcwd()

somepath = os.path.abspath(
    os.path.join(current_directory, '..', 'Data', 'AvelumabCohort', 'RNA_dataset_tabular_R3.csv'))

# expression data
tabular_data = pd.read_csv(somepath, sep = ',', index_col = 0)
original_gene_data = tabular_data
original_gene_data
# Out:
#                                    NFKB1  TNIP2  AMOT  VASP  SS18L1  SMARCA4  \
# id
# X00936b9285d6b8665ae9122993fb8e91   6.10   4.38  3.07  6.14    4.70     7.52
# X105622fadc33f23755ac2df823110aca   5.07   3.33  1.73  5.11    5.62     6.58
# Xe44f39747a8e84b02b4cb24659312144   6.13   4.41  3.23  6.32    5.57     8.02
# X293dd1284496215e9a0eca9f17a98e7e   5.82   4.30  3.44  6.45    4.86     7.45
# X01ed7190ce00862696edbf047b542045   6.15   4.21  3.90  5.93    4.43     7.60
# ...                                  ...    ...   ...   ...     ...      ...
# X50772aa64efb859960b20f8801cd6f58   6.27   3.78  3.98  5.95    4.66     7.18
# X91bcd3067a1a7954692d836515e04869   6.12   3.94  3.25  6.09    4.98     7.32
# Xc7439a06ffa32b313b0ec1b987b992a2   5.91   3.62  3.34  5.80    8.86     8.69
# X21a6043653d187f8bbead475d2f49791   6.48   4.32  2.27  6.10    5.13     7.83
# Xa021f5de25a2ffa059870f059a65d075   5.76   4.79  3.19  6.37    4.51     8.03
#
# ...

# %%
original_columns = list(original_gene_data.columns)
original_columns
# Out:
# ['NFKB1',
#  'TNIP2',
#  'AMOT',
#  'VASP',
#  'SS18L1',
#  'SMARCA4',
#  'SMURF1',
#  'HSPA5',
#  'SKIL',
#  'UBE2I',
#  'RAC1',
#  'ARL2BP',
#  'SNRPC',
#  'EIF4A3',
#  'TIPRL',
#  'PPP6C',
#  'SETDB1',
#  'PIN1',
#  'TSC22D4',
#  'CDK12',
#  'TRA2B',
#  'DVL1',
#  'AXIN1',
#  'REST',
#  'TRIM13',
#  'ARHGDIA',
#  'NPC2',
#  'NPC1',
#  'MAP2K1',
#  'CFLAR',
#  'SIAH1',
#  'RBBP8',
#  'VAPB',
#  'PKD1',
#  'ACTN1',
#  'LGR4',
#  'NCAPD3',
#  'PCMT1',
#  'TIMP2',
#  'RC3H1',
#  'UBE2G2',
#  'RYK',
#  'PRKDC',
#  'MAPK14',
#  'ELK3',
#  'TERF2',
#  'CTCF',
#  'HMGB1',
#  'RNF20',
#  'WAC',
#  'NUDT21',
#  'HDAC2',
#  'MOV10',
#  'USP11',
#  'BTRC',
#  'CDC26',
#  'ANAPC7',
#  'TLE4',
#  'FBXW7',
#  'MED4',
#  'BAG6',
#  'WDR83',
#  'NID1',
#  'MED1',
#  'HDAC5',
#  'TFRC',
#  'YWHAH',
#  'PAK2',
#  'GNA13',
#  'TGFBR1',
#  'CSNK2A1',
#  'SRSF10',
#  'PHGDH',
#  'GRB2',
#  'SMARCD1',
#  'GIGYF1',
#  'ELAVL1',
#  'DICER1',
#  'RBFOX2',
#  'ATXN2',
#  'CCND1',
#  'ORC4',
#  'GATA2',
# ...

# %% [markdown]
# -------------------
# -----------
# ----------

# %% [markdown]
# ### Genetic data

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = 'C://Users//inigo//Desktop//AAU//Cursos//4th semester//P10//Data//NivolumabCohort//otherCohort_geneticData.csv'

# Read the CSV file into a DataFrame
try:
    df_gen = pd.read_csv(file_path, sep = ";", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
df_gen.index.name = None
df_gen = df_gen.transpose()
df_gen
# Out:
#                   5S_rRNA          7SK         A1BG     A1BG-AS1         A1CF  \
# EA595454      21,02628588  36,97789665  30,21645496  25,84274915  31,39821353
# EA595455      21,02628588  38,12815927  29,34838892  18,91196024  34,13197197
# EA595473      21,02628588  35,37440093  31,17895807  25,11020389  32,16738112
# EA595500      21,02628588  37,80029684  29,69901116  25,35700279  32,64212068
# EA595522      21,02628588   37,5097892    30,122608  21,79811937  33,38868939
# ...                   ...          ...          ...          ...          ...
# RCC_73_T_SCR   21,0380433  36,33872887  30,95440674    27,310879  26,16156716
# RCC_90_T_SCR   21,0380433  38,24891513  33,11014903  26,79319909  26,16156716
# RCC_93_T_SCR   21,0380433  35,88481158  32,88028258  25,65984218  31,82294199
# RCC_96_T_SCR   21,0380433  35,28377564  30,65871464  27,53389014  32,93051233
# RCC_99_T_SCR   21,0380433  36,69454567  27,11867773  17,78872565  33,12869686
#
# ...

# %%
original_columns_filtered = [x for x in list(df_gen.columns) if x in original_columns]
df_gen = df_gen[original_columns_filtered]
df_gen = df_gen.replace(',', '.', regex=True)
df_gen
# Out:
#                    A4GALT         AAAS         AAMP        ABCA1        ABCA2  \
# EA595454      32.17196908  34.24260109  33.26724906  35.85706474  33.48000677
# EA595455      32.64151151  35.01693545  34.41901842  35.72138057  34.10730878
# EA595473      33.00614952  34.26072377  34.66440134   34.6950108  33.23682112
# EA595500      32.05277977   34.0659145  32.34165477  35.62946939  34.03010573
# EA595522      33.29307354  34.57446275  35.25024782  35.64774951  33.85236411
# ...                   ...          ...          ...          ...          ...
# RCC_73_T_SCR  32.36507381  34.74216697  33.11303877  33.74754641  33.93162948
# RCC_90_T_SCR  30.12136832  33.79240948   34.4509993  34.37121958  31.79981096
# RCC_93_T_SCR  31.95398362  34.14686117  33.67633386  35.38678117  32.61150111
# RCC_96_T_SCR   33.2551448  35.13836173  33.80858256  36.07228623  34.59809783
# RCC_99_T_SCR  33.37364386  34.74762925  35.75714238  33.91659118  34.16914481
#
# ...

# %%
df_gen.to_csv('output_GeneticData.csv', index=True)

# %% [markdown]
# --------------

# %% [markdown]
# ### Clinical data

# %%
# Assuming the CSV file is located in a folder named 'data' which is a subdirectory of the current directory
file_path = 'C://Users//inigo//Desktop//AAU//Cursos//4th semester//P10//Data//NivolumabCohort//otherCohort_clinicalData.csv'

# Read the CSV file into a DataFrame
try:
    df_cli = pd.read_csv(file_path, sep = ";", index_col = 0)
    print("CSV file successfully read.")  # Indicate successful reading
except FileNotFoundError:
    print("File not found. Please check the file path.")  # Handle file not found error

# Now you can use 'df' DataFrame for further analysis
# Out:
# CSV file successfully read.

# %%
df_cli
# Out:
#            Cohort        Arm                            MAF_Tumor_ID  \
# SUBJID
# RCC10-100  CM-010  NIVOLUMAB                                     NaN
# RCC10-105  CM-010  NIVOLUMAB                                     NaN
# RCC10-20   CM-010  NIVOLUMAB                                     NaN
# RCC10-71   CM-010  NIVOLUMAB                                     NaN
# RCC10-97   CM-010  NIVOLUMAB  RP-1458_RCCBMS-00097-T_v4_Exome_OnPrem
# ...           ...        ...                                     ...
# RCC_90     CM-009  NIVOLUMAB                   RCC_90-Tumor-SM-A46F3
# RCC_93     CM-009  NIVOLUMAB                   RCC_93-Tumor-SM-A46F8
# RCC_96     CM-009  NIVOLUMAB                   RCC_96-Tumor-SM-A46FW
# RCC_97     CM-009  NIVOLUMAB                   RCC_97-Tumor-SM-A46EW
# RCC_99     CM-009  NIVOLUMAB                   RCC_99-Tumor-SM-A46F7
#
#                                     MAF_Normal_ID  \
# SUBJID
# RCC10-100                                     NaN
# ...

# %%
for col in df_cli.columns:
    print(col)
# Out:
# Cohort
# Arm
# MAF_Tumor_ID
# MAF_Normal_ID
# CNV_ID
# RNA_ID
# CD8_IF_ID
# Sex
# Age
# MSKCC
# IMDC
# Sarc
# Rhab
# Sarc_or_Rhab
# Received_Prior_Therapy
# Number_of_Prior_Therapies
# Days_from_TumorSample_Collection_and_Start_of_Trial_Therapy
# SampleType
# Tumor_Sample_Primary_or_Metastasis
# Site_of_Metastasis
# Tumor_Shrinkage
# ORR
# Benefit
# ExtremeResponder
# PFS
# PFS_CNSR
# OS
# OS_CNSR
# irORR
# irPFS
# irPFS_CNSR
# Purity
# Ploidy
# TM_Area
# TM_CD8
# TM_CD8_Density
# TC_Area
# TC_CD8
# TC_CD8_Density
# TM_TC_Ratio
# ImmunoPhenotype
# TM_CD8_PERCENT
# TC_CD8_PERCENT
# TMB_Counts
# FS_Counts
# NEO_Weak
# WGII
# ITH
# homozygous_ANY
# Amplification_1p36.32
# Amplification_1q21.3
# Amplification_1q32.1
# Amplification_2q37.3
# Amplification_5p15.33
# Amplification_5q31.3
# Amplification_5q35.3
# Amplification_6p21.2
# Amplification_6q21
# Amplification_7p22.2
# Amplification_7q36.2
# Amplification_8p11.21
# Amplification_8q24.3
# Amplification_9q34.11
# ...

# %%
df_cli = df_cli.dropna(subset=['RNA_ID'])
df_cli = df_cli[['Arm', 'RNA_ID', 'PFS', 'PFS_CNSR']]
df_cli = df_cli.set_index('RNA_ID')
df_cli.rename(columns={'Arm': 'TRT01P'}, inplace=True)
df_cli.rename(columns={'PFS_CNSR': 'PFS_P_CNSR'}, inplace=True)
df_cli.rename(columns={'PFS': 'PFS_P'}, inplace=True)
df_cli = df_cli.replace(',', '.', regex=True)
df_cli
# Out:
#                                          TRT01P        PFS_P  PFS_P_CNSR
# RNA_ID
# G138701_RCCBMS-00020-T_v1_RNA_OnPrem  NIVOLUMAB  12.16438356           1
# G138701_RCCBMS-00097-T_v1_RNA_OnPrem  NIVOLUMAB  5.490410959           1
# G138701_RCCBMS-00141-T_v1_RNA_OnPrem  NIVOLUMAB  61.90684932           0
# G138701_RCCBMS-00099-T_v1_RNA_OnPrem  NIVOLUMAB  1.249315068           1
# G138701_RCCBMS-00163-T_v1_RNA_OnPrem  NIVOLUMAB  5.654794521           1
# ...                                         ...          ...         ...
# RCC_73_T_SCR                          NIVOLUMAB  1.906849315           1
# RCC_90_T_SCR                          NIVOLUMAB  1.183561644           1
# RCC_93_T_SCR                          NIVOLUMAB  16.43835616           1
# RCC_96_T_SCR                          NIVOLUMAB  1.216438356           1
# RCC_99_T_SCR                          NIVOLUMAB  1.347945205           1
#
# [311 rows x 3 columns]

# %%
df_cli.to_csv('output_ClinicalData.csv', index=True)
